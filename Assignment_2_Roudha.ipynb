# %% [markdown]
# <a href="https://colab.research.google.com/github/RoudhaAlmutawa/Assignment-2/blob/main/Assignment_2_Roudha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#the code below shocases an software application for the Louver Museum with diffrent classes to represrnt it.
from datetime import datetime

class Artwork:
  """a class to represent an artwork"""
  #the init fucntion is added as a constructor to initialize the artwork attributes
  #assigning the attributes values such as empty string
  def __init__(self, artTitle="", artist="", dateOfCreation=None, historicalSignificance="", artworkLocation=""):
    self.artTitle= artTitle
    self.artist= artist
    self.dateOfCreation= dateOfCreation
    self.historicalSignificance= historicalSignificance
    self.artworkLocation= artworkLocation

  #method to display information about artwork
  def displayInformation(self):
    pass

#adding the setter and getter functions for the class Artwork
  def get_artTitle(self):
        return self.artTitle
  def set_artTitle(self, artTitle):
        self.artTitle = artTitle

  def get_artist(self):
        return self.artist
  def set_artist(self, artist):
        self.artist = artist

  def get_dateOfCreation(self):
        return self.dateOfCreation
  def set_dateOfCreation(self, dateOfCreation):
        self.dateOfCreation = dateOfCreation

  def get_historicalSignificance(self):
        return self.historicalSignificance
  def set_historicalSignificance(self, historicalSignificance):
        self.historicalSignificance = historicalSignificance

  def get_artworkLocation(self):
        return self.artworkLocation
  def set_artworkLocation(self, artworkLocation):
        self.artworkLocation = artworkLocation

class Visitor:
  """a class to represnet a visitor"""
  #the init function is added as a constructor to initialize the visitor attributes
  #assigning the attributs values such as empty string
  def __init__(self, name="", age=0, nationality="", contactInformation=""):
    self.name= name
    self.age= age
    self.nationality= nationality
    self.contactInformation= contactInformation

#method to calculate the visitors age
  def calculateAge(self):
    pass

#adding the setter and getter functions for the class Visitor
  def get_name(self):
        return self.name
  def set_name(self, name):
        self.name = name

  def get_age(self):
        return self.age

  def set_age(self, age):
        self.age = age

  def get_nationality(self):
        return self.nationality
  def set_nationality(self, nationality):
        self.nationality = nationality

  def get_contactInformation(self):
        return self.contactInformation
  def set_contactInformation(self, contactInformation):
        self.contactInformation = contactInformation

class VisitorCategory:
  """a class to represent the visitor category"""
  #the init function is added as a constructor to initialize the Visitor Category attributes
  #assigning the attributs values
  def __init__(self, ageRange=None):
    self.ageRange= ageRange

#adding the setter and getter functions for the class VisitorCategory
  def get_ageRange(self):
        return self.ageRange
  def set_ageRange(self, ageRange):
        self.ageRange = ageRange

class Ticket:
  """a class to reprenet a ticket"""
  #the init function is added as a constructor to initialize the ticket attributes
  #assigning the attributs values
  def __init__(self, ticketType="", price=0.0, purchaseDate=None, visitorInformation=None, details=""):
    self.ticketType= ticketType
    self.price= price
    self.purchaseDate= purchaseDate
    self.visitorInformation= visitorInformation   # One-to-one association with Visitor
    self.details= details

#method to claculate the final price of the ticket
  def initcalculateFinalPrice(self):
    pass
#method to display the details of the ticket
  def displayTicketDetails(self):
    pass

#adding the setter and getter functions for the class ticket
  def get_ticketType(self):
    return self.ticketType
  def set_ticketType(self, ticketType):
    self.ticketType =ticketType

  def get_price(self):
    return self.price
  def set_price(self, price):
    self.price= price

  def get_purchaseDate(self):
    return self.purchaseDate
  def set_purchaseDate(self, purchaseDate):
    self.purchaseDate= purchaseDate

  def get_visitorInformation(self):
    return self.visitorInformation
  def set_visitorInformation(self, visitorInformation):
    self.visitorInformation= visitorInformation

  def get_details(self):
    return self.details
  def set_details(self, details):
    self.details= details

class Pricing:
  """a class to represent the pricing"""
  #the init function is added as a constructor to initialize the pricing attributes
  #assigning the attributs values
  def __init__(self, adultPrice=0.0, childPrice=0.0, groupDiscount=0.0, vat=0.0):
    self.adultPrice= adultPrice
    self.childPrice= childPrice
    self.groupDiscount= groupDiscount
    self.vat= vat

#Method to update the pricing information
  def updatePrices(self):
    pass

# Method to calculate the discounted price
  def calculateDiscountedPrice(self):
    pass

#adding the setter and getter functions for the class Pricing
  def get_adultPrice(self):
        return self.adultPrice
  def set_adultPrice(self, adultPrice):
        self.adultPrice = adultPrice

  def get_childPrice(self):
        return self.childPrice
  def set_childPrice(self, childPrice):
        self.childPrice = childPrice

  def get_groupDiscount(self):
        return self.groupDiscount
  def set_groupDiscount(self, groupDiscount):
        self.groupDiscount = groupDiscount

  def get_vat(self):
        return self.vat
  def set_vat(self, vat):
        self.vat = vat

class Exhibition:
  """a class to reprenstn an exhibition"""
  #the init function is added as a constructor to initialize the exhibition attributes
  #assigning the attributs values
  def __init__(self, title= "", location="", duration=0):
    self.title= title
    self.location=location  #association with Location
    self.duration= duration

# Method to update the location of the exhibition
  def updateLocation(self):
    pass

#adding the setter and getter functions for the class Exhibition
  def get_title(self):
    return self.title
  def set_title(self, title):
    self.title= title

  def get_location(self):
    return self.location
  def set_location(self, location):
    self.location= location

  def get_duration(self):
    return self.duration
  def set_duration(self, duration):
    self.duration= duration

class Location:
  """a class to reprenstn an location"""
  #the init function is added as a constructor to initialize the location attributes
  #assigning the attributs values
  def __init__(self, locationName=""):
    self.locationName= locationName

#Method to get the capacity of the location
  def getCapacity(self):
    pass

#adding the setter and getter functions for the class Location
  def get_locationName(self):
    return self.locationName
  def set_locationName(self, locationName):
    self.locationName= locationName

  def get_capacity(self):
    return self.capacity
  def set_capacity(self, capacity):
    self.capacity= capacity

class Tour:     # Inheritance relationship with Exhibition
  """a class to reprenstn the Tour"""
  #the init function is added as a constructor to initialize the Tour attributes
  #assigning the attributs values
  def __init__(self, date=None, groupSize=0, guide=""):
    super().__init__()     # Calling the superclass constructor
    self.date= date
    self.groupSize= groupSize
    self.guide= guide
    self.artworks = []  # Aggregation relationship with Artwork

#Method to check if the tour is full
  def isFull(self):
    pass

#Method to add the artwork to the tour
  def addArtwork(self, artwork):
    self.artworks.append(artwork)

#adding the setter and getter functions for the class Tour
  def get_date(self):
    return self.date
  def set_date(self, date):
    self.date= date

  def get_groupSize(self):
    return self.groupSize
  def set_groupSize(self, groupSize):
    self.groupSize= groupSize

  def get_guide(self):
    return self.guide
  def set_guide(self, guide):
    self.guide= guide

class SpecialEvent:
  """a class to reprenstn the Special Event"""
  #the init function is added as a constructor to initialize the Special Event attributes
  #assigning the attributs values
  def __init__(self, title="", location="", duration=0):
    self.title = title
    self.location = location  # association with Location

# Method to check if the special event is happening now
  def isHappeningNow(self):
    pass

#adding the setter and getter functions for the class SpecialEvent
  def get_title(self):
    return self.title
  def set_title(self, title):
    self.title= title

  def get_location(self):
        return self.location
  def set_location(self, location):
        self.location = location

# %% [markdown]
# # Test cases

# %%
#Test case 1: this test cases addes the new artwoek to the museum
artwork1= Artwork("mona lisa", "Leonardo da Vinci", datetime(1503, 1, 1), "Famous portrait", "Permanent Gallery")
artwork2 = Artwork("The Starry Night", "Vincent van Gogh", datetime(1889, 6, 1), "Iconic post-impressionist painting", "Special Exhibition Hall")
meseum_catalog= [artwork1, artwork2]

print("Updated Museum Catalog:")
for artwork in meseum_catalog:
    print("- Title:", artwork.artTitle)
    print("  Artist:", artwork.artist)
    print("  Date of Creation:", artwork.dateOfCreation)
    print("  Location:", artwork.artworkLocation)
# Out:
# Updated Museum Catalog:
# - Title: mona lisa
#   Artist: Leonardo da Vinci
#   Date of Creation: 1503-01-01 00:00:00
#   Location: Permanent Gallery
# - Title: The Starry Night
#   Artist: Vincent van Gogh
#   Date of Creation: 1889-06-01 00:00:00
#   Location: Special Exhibition Hall

# %%
#test case 2: this test cases opens a new exhibition/event
exhibition1 = Exhibition("Impressionist Masters", "Exhibition Hall A", 30)
event1 = SpecialEvent("Musical Concert", "Outdoor Stage", 120)
# Adds exhibition and event to museum schedule
museum_schedule = [exhibition1, event1]

print("\nUpdated Museum Schedule:")
for event in museum_schedule:
    print("- Title:", event.title)
    print("  Location:", event.location)
    print()
# Out:
# Updated Museum Schedule:
# - Title: Impressionist Masters
#   Location: Exhibition Hall A
#
# - Title: Musical Concert
#   Location: Outdoor Stage

# %%
#test case 3: this test case is for the purchase of tickets
visitor1 = Visitor("Roudha", 19,"UAE", "roudha@gmail.com")
visitor_category1 = VisitorCategory((18, 60))
visitor_category1 = VisitorCategory((18, 60))  # Adult
ticket1 = Ticket("Regular", 63.0, datetime.now(), visitor1, "General Admission")
ticket2 = Ticket("Child", 0.0, datetime.now(), visitor1, "Children under 18")
ticket3 = Ticket("Senior", 0.0, datetime.now(), visitor1, "Seniors above 60")
ticket4 = Ticket("Group", 31.5, datetime.now(), visitor1, "Group Discount")

total_bill = ticket1.price + ticket2.price + ticket3.price + ticket4.price  # Calculate total bill
total_bill_with_vat = total_bill * 1.05  # Apply VAT

print("\nTicket Details:")
print("Ticket 1 - Regular:", ticket1.price, "AED")
print("Ticket 2 - Child:", ticket2.price, "AED")
print("Ticket 3 - Senior:", ticket3.price, "AED")
print("Ticket 4 - Group:", ticket4.price, "AED")
print("Total Bill (incl. VAT):", total_bill_with_vat, "AED")
# Out:
# Ticket Details:
# Ticket 1 - Regular: 63.0 AED
# Ticket 2 - Child: 0.0 AED
# Ticket 3 - Senior: 0.0 AED
# Ticket 4 - Group: 31.5 AED
# Total Bill (incl. VAT): 99.22500000000001 AED

# %%
# Test Case 4: this test cases tests the purchases of tickets for a special event
special_event_ticket = Ticket("SpecialEvent", 100.0, datetime.now(), visitor1, "VIP Pass")
print("\nSpecial Event Ticket Details:")
print("Ticket Type:", special_event_ticket.ticketType)
print("Price:", special_event_ticket.price, "AED")
print("Purchase Date:", special_event_ticket.purchaseDate)
print("Visitor Information:", special_event_ticket.visitorInformation.get_name())
print("Details:", special_event_ticket.details)
# Out:
# Special Event Ticket Details:
# Ticket Type: SpecialEvent
# Price: 100.0 AED
# Purchase Date: 2024-03-30 23:52:55.598099
# Visitor Information: Roudha
# Details: VIP Pass
